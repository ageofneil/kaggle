# %%
import nltk
import re

# %%
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#import plotly.express as px

from pandas_profiling import ProfileReport
from sklearn import metrics
from sklearn.preprocessing import OrdinalEncoder
from xgboost import XGBClassifier

# %%
KAGGLE_EVAL_METRIC = 'logloss' # string name for loss function in xgboost

# %%
TRAIN_PATH = "data/train.csv"
TEST_PATH = "data/test.csv"

# %% [markdown]
# # Load Data

# %%
train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)

# %% [markdown]
# ## TESTS

# %%
len(['1212'])
# Out:
# 1

# %%
def replace_number(ticket, number):
    x = ticket.replace(str(number), '')
    return x

# %%
train.Ticket = train.Ticket.str.lower()

# %%
def replace_number(ticket, number):
    x = ticket.replace(str(number), '')
    return x

train.Ticket = train.Ticket.str.lower()

train['temp'] = train.Ticket.str.split()
train['Ticket Number'] = train.temp.apply(lambda x: x[-1])
train["Ticket Number"] = train["Ticket Number"].str.replace('line','0')
train["Ticket Number"] = train["Ticket Number"].astype(int)
train['Ticket Type'] = train.apply(lambda x: replace_number(x['Ticket'], x['Ticket Number']), axis=1)
train = train.drop(['Ticket','temp'],axis=1)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train['Ticket Type'].unique()
# Out:
# array(['a/5 ', 'pc ', 'ston/o2. ', '', 'pp ', 'a/5. ', 'c.a. ', 'a./5. ',
#        'sc/paris ', 's.c./a.4. ', 'a/4. ', 'ca ', 's.p. ', 's.o.c. ',
#        'so/c ', 'w./c. ', 'soton/oq ', 'w.e.p. ', 'ston/o 2. ', 'a4. ',
#        'c ', 'soton/o.q. ', 's.o.p. ', 'a.5. ', 'fa ', 'ca. ', 'line',
#        'f.c.c. ', 'w/c ', 'sw/pp ', 'sco/w ', 'p/pp ', 'sc ', 'sc/ah ',
#        'a/s ', 'sc/ah basle ', 'a/4 ', 'we/p ', 's.w./pp ', 's.o./p.p. ',
#        'f.c. ', 'soton/o2 ', 's.c./paris ', 'c.a./soton '], dtype=object)
